# %%
from IPython.display import display, Markdown, Latex
from get_datasets import *
import re

# %%
src_total_data = datasets.load(source, bk[source], seed=params.SEED)

# %% [markdown]
# ## Backgrounds

# %%
bk = {
      'imdb': ['workedunder(+person,+person).',
              'workedunder(+person,-person).',
              'workedunder(-person,+person).',
              #'recursion_workedunder(+person,`person).',
              #'recursion_workedunder(`person,+person).',
              'female(+person).',
              'actor(+person).',
              'director(+person).',
              'movie(+movie,+person).',
              'movie(+movie,-person).',
              'movie(-movie,+person).',
              'genre(+person,+genre).'],
      'uwcse': ['professor(+person).',
        'student(+person).',
        'advisedby(+person,+person).',
        'advisedby(+person,-person).',
        'advisedby(-person,+person).',
        #'recursion_advisedby(`person,+person).',
        #'recursion_advisedby(+person,`person).',
        'tempadvisedby(+person,+person).',
        'tempadvisedby(+person,-person).',
        'tempadvisedby(-person,+person).',
        'ta(+course,+person,+quarter).',
        'ta(-course,-person,+quarter).',
        'ta(+course,-person,-quarter).',
        'ta(-course,+person,-quarter).',
        'hasposition(+person,+faculty).',
        'hasposition(+person,-faculty).',
        'hasposition(-person,+faculty).',
        'publication(+title,+person).',
        'publication(+title,-person).',
        'publication(-title,+person).',
        'inphase(+person,+prequals).',
        'inphase(+person,-prequals).',
        'inphase(-person,+prequals).',
        'courselevel(+course,+level).',
        'courselevel(+course,-level).',
        'courselevel(-course,+level).',
        'yearsinprogram(+person,+year).',
        'yearsinprogram(-person,+year).',
        'yearsinprogram(+person,-year).',
        'projectmember(+project,+person).',
        'projectmember(+project,-person).',
        'projectmember(-project,+person).',
        'sameproject(+project,+project).',
        'sameproject(+project,-project).',
        'sameproject(-project,+project).',
        'samecourse(+course,+course).',
        'samecourse(+course,-course).',
        'samecourse(-course,+course).',
        'sameperson(+person,+person).',
        'sameperson(+person,-person).',
        'sameperson(-person,+person).',],
      'cora': ['sameauthor(+author,+author).',
              'sameauthor(+author,-author).',
              'sameauthor(-author,+author).',
              'samebib(+class,+class).',
              'samebib(+class,-class).',
              'samebib(-class,+class).',
              'sametitle(+title,+title).',
              'sametitle(+title,-title).',
              'sametitle(-title,+title).',
              'samevenue(+venue,+venue).',
              'samevenue(+venue,-venue).',
              'samevenue(-venue,+venue).',
              #'recursion_samevenue(+venue,`venue).',
              #'recursion_samevenue(`venue,+venue).',
              'author(+class,+author).',
              'author(+class,-author).',
              'author(-class,+author).',
              'title(+class,+title).',
              'title(+class,-title).',
              'title(-class,+title).',
              'venue(+class,+venue).',
              'venue(+class,-venue).',
              'venue(-class,+venue).',
              'haswordauthor(+author,+word).',
              'haswordauthor(+author,-word).',
              'haswordauthor(-author,+word).',
              'haswordtitle(+title,+word).',
              'haswordtitle(+title,-word).',
              'haswordtitle(-title,+word).',
              'haswordvenue(+venue,+word).',
              'haswordvenue(+venue,-word).',
              'haswordvenue(-venue,+word).'],
      'webkb': ['coursepage(+page).',
                'facultypage(+page).',
                'studentpage(+page).',
                'researchprojectpage(+page).',
                'linkto(+id,+page,+page).',
                'linkto(+id,-page,-page).',
                'linkto(-id,-page,+page).',
                'linkto(-id,+page,-page).',
                'has(+word,+page).',
                'has(+word,-page).',
                'has(-word,+page).',
                'hasalphanumericword(+id).',
                'allwordscapitalized(+id).',
                'instructorsof(+page,+page).',
                'instructorsof(+page,-page).',
                'instructorsof(-page,+page).',
                'hasanchor(+word,+page).',
                'hasanchor(+word,-page).',
                'hasanchor(-word,+page).',
                'membersofproject(+page,+page).',
                'membersofproject(+page,-page).',
                'membersofproject(-page,+page).',
                'departmentof(+page,+page).',
                'departmentof(+page,-page).',
                'departmentof(-page,+page).',
                'pageclass(+page,+class).',
                'pageclass(+page,-class).',
                'pageclass(-page,+class).'],
      'twitter': ['accounttype(+account,+type).',
                  'accounttype(+account,-type).',
                  'accounttype(-account,+type).',
                  #'typeaccount(+type,`account).',
                  #'typeaccount(`type,+account).',
                  'tweets(+account,+word).',
                  'tweets(+account,-word).',
                  'tweets(-account,+word).',
                  'follows(+account,+account).',
                  'follows(+account,-account).',
                  'follows(-account,+account).',
                  'recursion_accounttype(+account,`type).',
                  'recursion_accounttype(`account,+type).',],
      'yeast': ['location(+protein,+loc).',
                'location(+protein,-loc).',
                'location(-protein,+loc).',
                'interaction(+protein,+protein).',
                'interaction(+protein,-protein).',
                'interaction(-protein,+protein).',
                'proteinclass(+protein,+class).',
                'proteinclass(+protein,-class).',
                'proteinclass(-protein,+class).',
                #'classprotein(+class,`protein).',
                #'classprotein(`class,+protein).',
                'enzyme(+protein,+enz).',
                'enzyme(+protein,-enz).',
                'enzyme(-protein,+enz).',
                'function(+protein,+fun).',
                'function(+protein,-fun).',
                'function(-protein,+fun).',
                'complex(+protein,+com).',
                'complex(+protein,-com).',
                'complex(-protein,+com).',
                'phenotype(+protein,+phe).',
                'phenotype(+protein,-phe).',
                'phenotype(-protein,+phe).',
                'recursion_proteinclass(+protein,`class).',
                'recursion_proteinclass(`protein,+class).'],
      'nell_sports': ['athleteledsportsteam(+athlete,+sportsteam).',
              'athleteledsportsteam(+athlete,-sportsteam).',
              'athleteledsportsteam(-athlete,+sportsteam).',
              'athleteplaysforteam(+athlete,+sportsteam).',
              'athleteplaysforteam(+athlete,-sportsteam).',
              'athleteplaysforteam(-athlete,+sportsteam).',
              'athleteplaysinleague(+athlete,+sportsleague).',
              'athleteplaysinleague(+athlete,-sportsleague).',
              'athleteplaysinleague(-athlete,+sportsleague).',
              'athleteplayssport(+athlete,+sport).',
              'athleteplayssport(+athlete,-sport).',
              'athleteplayssport(-athlete,+sport).',
              'teamalsoknownas(+sportsteam,+sportsteam).',
              'teamalsoknownas(+sportsteam,-sportsteam).',
              'teamalsoknownas(-sportsteam,+sportsteam).',
              'teamplaysagainstteam(+sportsteam,+sportsteam).',
              'teamplaysagainstteam(+sportsteam,-sportsteam).',
              'teamplaysagainstteam(-sportsteam,+sportsteam).',
              'teamplaysinleague(+sportsteam,+sportsleague).',
              'teamplaysinleague(+sportsteam,-sportsleague).',
              'teamplaysinleague(-sportsteam,+sportsleague).',
              'teamplayssport(+sportsteam,+sport).',
              'teamplayssport(+sportsteam,-sport).',
              'teamplayssport(-sportsteam,+sport).',
              'teamplayssport(+sportsteam,`sport).',
              'teamplayssport(`sportsteam,+sport).'],
              #'recursion_teamplayssport(`sportsteam,+sport).',
              #'recursion_teamplayssport(+sportsteam,`sport).'],
      'nell_finances': ['countryhascompanyoffice(+country,+company).',
                        'countryhascompanyoffice(+country,-company).',
                        'countryhascompanyoffice(-country,+company).',
                        'companyeconomicsector(+company,+sector).',
                        'companyeconomicsector(+company,-sector).',
                        'companyeconomicsector(-company,+sector).',
                        'economicsectorcompany(+sector,`company).',
                        'economicsectorcompany(`sector,+company).',
                        #'recursion_economicsectorcompany(+sector,`company).',
                        #'recursion_economicsectorcompany(`sector,+company).',
                        #'economicsectorcompany(+sector,+company).',
                        #'economicsectorcompany(+sector,-company).',
                        #'economicsectorcompany(-sector,+company).',
                        #'ceoeconomicsector(+person,+sector).',
                        #'ceoeconomicsector(+person,-sector).',
                        #'ceoeconomicsector(-person,+sector).',
                        'companyceo(+company,+person).',
                        'companyceo(+company,-person).',
                        'companyceo(-company,+person).',
                        'companyalsoknownas(+company,+company).',
                        'companyalsoknownas(+company,-company).',
                        'companyalsoknownas(-company,+company).',
                        'cityhascompanyoffice(+city,+company).',
                        'cityhascompanyoffice(+city,-company).',
                        'cityhascompanyoffice(-city,+company).',
                        'acquired(+company,+company).',
                        'acquired(+company,-company).',
                        'acquired(-company,+company).',
                        #'ceoof(+person,+company).',
                        #'ceoof(+person,-company).',
                        #'ceoof(-person,+company).',
                        'bankbankincountry(+person,+country).',
                        'bankbankincountry(+person,-country).',
                        'bankbankincountry(-person,+country).',
                        'bankboughtbank(+company,+company).',
                        'bankboughtbank(+company,-company).',
                        'bankboughtbank(-company,+company).',
                        'bankchiefexecutiveceo(+company,+person).',
                        'bankchiefexecutiveceo(+company,-person).',
                        'bankchiefexecutiveceo(-company,+person).']}

# %%
experiments = [
            {'dataset':'imdb','predicate':'workedunder'},
            {'dataset':'uwcse','predicate':'advisedby'},
            {'dataset':'cora','predicate':'samevenue'},
            {'dataset':'yeast','predicate':'proteinclass', 'recursion': True},
            {'dataset':'twitter','predicate':'accounttype', 'recursion': True},
            {'dataset':'nell_sports','predicate':'teamplayssport'},
            {'dataset':'nell_finances','predicate':'companyeconomicsector'}
]

# %% [markdown]
# ## Process

# %%
table = []


for exp in experiments:
    dataset = exp['dataset']
    target_predicate = exp['predicate']
    
    dt = datasets.load(dataset, bk[dataset], target_predicate)
    number_predicates = len(set([pred.split('(')[0] for pred in bk[dataset]]))
    
    if 'recursion' in exp:
        number_predicates -= 1
    
    constants = []
    unique_constants = []
    unique_types = []
    true_ground_constants = []
    
    facts_ground_literals = datasets.group_folds(dt[0])
    true_ground_literals = datasets.group_folds(dt[1])
    negative_ground_literals = datasets.group_folds(dt[2])
    
    types = [re.search(r'\((.*?)\)', i).group(1).split(',') for i in bk[dataset]]
    
    for _type in types:
        unique_types += [t.replace('-','').replace('+', '').replace('`', '') for t in _type]
    
    number_true_ground_literals = len(true_ground_literals)
    true_ground_constants += [re.search(r'\((.*?)\)', i).group(1).split(',') for i in true_ground_literals]
    
    constants += [re.search(r'\((.*?)\)', i).group(1).split(',') for i in facts_ground_literals]
    constants += [re.search(r'\((.*?)\)', i).group(1).split(',') for i in negative_ground_literals]
    constants += true_ground_constants
    
    for c in constants:
        unique_constants += c
    
    type_1, type_2 = [], []
    for c in true_ground_constants:
        type_1 += c[0]
        type_2 += c[1]

    table.append([dataset,
                 len(set(unique_constants)), 
                 len(set(unique_types)),
                 number_predicates,
                 number_true_ground_literals,
                 len(set(type_1))*len(set(type_2))*number_true_ground_literals
                 ])
    
display(pd.DataFrame(table, columns=['Dataset', 'Number of Constants', 'Number of Types', 'Number of Predicates', 'Number of true ground literals', 'Total number of ground literals']))
# Out:
#          Dataset  Number of Constants  Number of Types  Number of Predicates  \
# 0           imdb                  297                3                     6
# 1          uwcse                  914                9                    14
# 2           cora                 2457                5                    10
# 3          yeast                 2470                7                     7
# 4        twitter                  273                3                     3
# 5    nell_sports                 4538                4                     8
# 6  nell_finances                 3340                5                    10
#
#    Number of true ground literals  Total number of ground literals
# 0                             382                           248300
# 1                             113                            28928
# 2                            3017                          3487652
# 3                             369                           154980
# 4                             282                            31020
# 5                             397                           175474
# 6                             778                           465244

# %%
unique_constants
# Out:
# [['asoderberghsteven', 'athriller'],
#  ['asoderberghsteven', 'acomedy'],
#  ['asoderberghsteven', 'adocumentary'],
#  ['asoderberghsteven', 'aaction'],
#  ['asoderberghsteven', 'acrime'],
#  ['apakulaalanj', 'athriller'],
#  ['apakulaalanj', 'adrama'],
#  ['apakulaalanj', 'amystery'],
#  ['aaltmanroberti', 'athriller'],
#  ['aaltmanroberti', 'acomedy'],
#  ['aaltmanroberti', 'adrama'],
#  ['aeddiejemison', 'asoderberghsteven'],
#  ['atimothypaulperez', 'asoderberghsteven'],
#  ['acaseyaffleck', 'asoderberghsteven'],
#  ['ajorgerhernandez', 'asoderberghsteven'],
#  ['astanleyanderson', 'apakulaalanj'],
#  ['atonygoldwyn', 'apakulaalanj'],
#  ['afrankpatton', 'asoderberghsteven'],
#  ['anicholaswoodeson', 'apakulaalanj'],
#  ['anelsonpeltz', 'asoderberghsteven'],
#  ['ajohnfinn', 'apakulaalanj'],
#  ['alorigalinski', 'asoderberghsteven'],
#  ['atimrobbins', 'aaltmanroberti'],
#  ['agretascacchi', 'aaltmanroberti'],
#  ['adontiffany', 'asoderberghsteven'],
#  ['abradpitt', 'asoderberghsteven'],
#  ['ajohnheard', 'apakulaalanj'],
#  ['aelliottgould', 'asoderberghsteven'],
#  ['aannejacques', 'asoderberghsteven'],
#  ['alylelovett', 'aaltmanroberti'],
#  ['acarolflorence', 'asoderberghsteven'],
#  ['aleahayres', 'aaltmanroberti'],
#  ['arobertculp', 'apakulaalanj'],
#  ['adinaconnolly', 'asoderberghsteven'],
#  ['aandygarcia', 'asoderberghsteven'],
#  ['adenzelwashington', 'apakulaalanj'],
#  ['aberniemac', 'asoderberghsteven'],
#  ['acynthiastevenson', 'aaltmanroberti'],
#  ['adeanstockwell', 'aaltmanroberti'],
#  ['aanthonyheald', 'apakulaalanj'],
#  ['ahumecronyn', 'apakulaalanj'],
#  ['adinamerrill', 'aaltmanroberti'],
#  ['apetergallagher', 'aaltmanroberti'],
#  ['aangelahall', 'aaltmanroberti'],
#  ['ajohnlithgow', 'apakulaalanj'],
#  ['ajamessikking', 'apakulaalanj'],
#  ['alarrysontag', 'asoderberghsteven'],
#  ['avincentdonofrio', 'aaltmanroberti'],
#  ['abrionjames', 'aaltmanroberti'],
#  ['afredward', 'aaltmanroberti'],
#  ['amarkgantt', 'asoderberghsteven'],
#  ['astanleytucci', 'apakulaalanj'],
#  ['apaullnolan', 'asoderberghsteven'],
#  ['arichardegrant', 'aaltmanroberti'],
#  ['acatherinezetajones', 'asoderberghsteven'],
#  ['asamshepard', 'apakulaalanj'],
#  ['awhoopigoldberg', 'aaltmanroberti'],
#  ['ajuliaroberts', 'asoderberghsteven'],
#  ['ajuliaroberts', 'apakulaalanj'],
#  ['ageorgeclooney', 'asoderberghsteven'],
#  ['adavidsontag', 'asoderberghsteven'],
#  ['awilliamatherton', 'apakulaalanj'],
#  ['asydneypollack', 'aaltmanroberti'],
#  ['aminianden', 'asoderberghsteven'],
#  ['ascottcaan', 'asoderberghsteven'],
#  ['aceceliaannbirt', 'asoderberghsteven'],
#  ['aedkross', 'asoderberghsteven'],
#  ['aeddiejemison'],
#  ['atimothypaulperez'],
#  ['acaseyaffleck'],
#  ['ajorgerhernandez'],
#  ['afrankpatton'],
#  ['alorigalinski'],
#  ['agretascacchi'],
#  ['abradpitt'],
#  ['aelliottgould'],
#  ['aannejacques'],
#  ['acarolflorence'],
#  ['aleahayres'],
#  ['adinaconnolly'],
#  ['aberniemac'],
#  ['acynthiastevenson'],
#  ['adinamerrill'],
#  ['aangelahall'],
#  ['amarkgantt'],
#  ['apaullnolan'],
#  ['acatherinezetajones'],
#  ['awhoopigoldberg'],
#  ['ajuliaroberts'],
#  ['ageorgeclooney'],
#  ['aminianden'],
#  ['ascottcaan'],
#  ['aceceliaannbirt'],
#  ['aeddiejemison'],
#  ['atimothypaulperez'],
#  ['acaseyaffleck'],
#  ['ajorgerhernandez'],
#  ['astanleyanderson'],
#  ['atonygoldwyn'],
#  ['afrankpatton'],
#  ['anicholaswoodeson'],
#  ['anelsonpeltz'],
#  ['ajohnfinn'],
#  ['alorigalinski'],
#  ['atimrobbins'],
#  ['agretascacchi'],
#  ['adontiffany'],
#  ['abradpitt'],
#  ['ajohnheard'],
#  ['aelliottgould'],
#  ['aannejacques'],
#  ['alylelovett'],
#  ['acarolflorence'],
#  ['aleahayres'],
#  ['arobertculp'],
#  ['adinaconnolly'],
#  ['aandygarcia'],
#  ['adenzelwashington'],
#  ['aberniemac'],
#  ['acynthiastevenson'],
#  ['adeanstockwell'],
#  ['aanthonyheald'],
#  ['ahumecronyn'],
#  ['adinamerrill'],
#  ['apetergallagher'],
#  ['aangelahall'],
#  ['ajohnlithgow'],
#  ['ajamessikking'],
#  ['alarrysontag'],
#  ['avincentdonofrio'],
#  ['abrionjames'],
#  ['afredward'],
#  ['amarkgantt'],
#  ['astanleytucci'],
#  ['apaullnolan'],
#  ['arichardegrant'],
#  ['acatherinezetajones'],
#  ['asamshepard'],
#  ['awhoopigoldberg'],
#  ['ajuliaroberts'],
#  ['ageorgeclooney'],
#  ['adavidsontag'],
#  ['awilliamatherton'],
#  ['asydneypollack'],
#  ['aminianden'],
#  ['ascottcaan'],
#  ['aceceliaannbirt'],
#  ['aedkross'],
#  ['asoderberghsteven'],
#  ['apakulaalanj'],
#  ['aaltmanroberti'],
#  ['aoceanstwelve', 'acaseyaffleck'],
#  ['aoceanstwelve', 'anelsonpeltz'],
#  ['aoceanstwelve', 'adontiffany'],
#  ['aoceanstwelve', 'abradpitt'],
#  ['aoceanstwelve', 'aannejacques'],
#  ['aoceanstwelve', 'adinaconnolly'],
#  ['aoceanstwelve', 'aandygarcia'],
#  ['aoceanstwelve', 'alarrysontag'],
#  ['aoceanstwelve', 'acatherinezetajones'],
#  ['aoceanstwelve', 'ajuliaroberts'],
#  ['aoceanstwelve', 'ageorgeclooney'],
#  ['aoceanstwelve', 'adavidsontag'],
#  ['aoceanstwelve', 'aminianden'],
#  ['aoceanstwelve', 'ascottcaan'],
#  ['aoceanstwelve', 'aedkross'],
#  ['aoceanstwelve', 'asoderberghsteven'],
#  ['aplayerthe', 'atimrobbins'],
#  ['aplayerthe', 'agretascacchi'],
#  ['aplayerthe', 'alylelovett'],
#  ['aplayerthe', 'aleahayres'],
#  ['aplayerthe', 'acynthiastevenson'],
#  ['aplayerthe', 'adeanstockwell'],
#  ['aplayerthe', 'adinamerrill'],
#  ['aplayerthe', 'apetergallagher'],
#  ['aplayerthe', 'aangelahall'],
#  ['aplayerthe', 'avincentdonofrio'],
#  ['aplayerthe', 'abrionjames'],
#  ['aplayerthe', 'afredward'],
#  ['aplayerthe', 'arichardegrant'],
#  ['aplayerthe', 'awhoopigoldberg'],
#  ['aplayerthe', 'asydneypollack'],
#  ['aplayerthe', 'aaltmanroberti'],
#  ['apelicanbriefthe', 'astanleyanderson'],
#  ['apelicanbriefthe', 'atonygoldwyn'],
#  ['apelicanbriefthe', 'anicholaswoodeson'],
#  ['apelicanbriefthe', 'ajohnfinn'],
#  ['apelicanbriefthe', 'ajohnheard'],
#  ['apelicanbriefthe', 'arobertculp'],
#  ['apelicanbriefthe', 'adenzelwashington'],
#  ['apelicanbriefthe', 'aanthonyheald'],
#  ['apelicanbriefthe', 'ahumecronyn'],
#  ['apelicanbriefthe', 'ajohnlithgow'],
#  ['apelicanbriefthe', 'ajamessikking'],
#  ['apelicanbriefthe', 'astanleytucci'],
#  ['apelicanbriefthe', 'asamshepard'],
#  ['apelicanbriefthe', 'ajuliaroberts'],
#  ['apelicanbriefthe', 'awilliamatherton'],
#  ['apelicanbriefthe', 'apakulaalanj'],
#  ['aoceanseleven', 'aeddiejemison'],
#  ['aoceanseleven', 'atimothypaulperez'],
#  ['aoceanseleven', 'acaseyaffleck'],
#  ['aoceanseleven', 'ajorgerhernandez'],
#  ['aoceanseleven', 'afrankpatton'],
#  ['aoceanseleven', 'alorigalinski'],
#  ['aoceanseleven', 'abradpitt'],
#  ['aoceanseleven', 'aelliottgould'],
#  ['aoceanseleven', 'acarolflorence'],
#  ['aoceanseleven', 'aberniemac'],
#  ['aoceanseleven', 'amarkgantt'],
#  ['aoceanseleven', 'apaullnolan'],
#  ['aoceanseleven', 'ageorgeclooney'],
#  ['aoceanseleven', 'ascottcaan'],
#  ['aoceanseleven', 'aceceliaannbirt'],
#  ['aoceanseleven', 'asoderberghsteven'],
#  ['ametcalfestephen', 'acomedy'],
#  ['ametcalfestephen', 'adrama'],
#  ['ametcalfestephen', 'aromance'],
#  ['averhoevenpauli', 'athriller'],
#  ['averhoevenpauli', 'acrime'],
#  ['averhoevenpauli', 'adrama'],
#  ['averhoevenpauli', 'amystery'],
#  ['amillergeorgei', 'ascifi'],
#  ['acatonjonesmichael', 'athriller'],
#  ['acatonjonesmichael', 'acrime'],
#  ['acatonjonesmichael', 'adrama'],
#  ['acatonjonesmichael', 'amystery'],
#  ['amichaeldouglas', 'averhoevenpauli'],
#  ['arobyndouglass', 'amillergeorgei'],
#  ['alewissmith', 'amillergeorgei'],
#  ['abillyconnolly', 'ametcalfestephen'],
#  ['adanielvonbargen', 'averhoevenpauli'],
#  ['adenisarndt', 'averhoevenpauli'],
#  ['afloramontgomery', 'acatonjonesmichael'],
#  ['asheilapaterson', 'ametcalfestephen'],
#  ['astancollymore', 'acatonjonesmichael'],
#  ['abenjaminmouton', 'averhoevenpauli'],
#  ['ajeannetripplehorn', 'averhoevenpauli'],
#  ['aneilmaskell', 'acatonjonesmichael'],
#  ['asharonstone', 'ametcalfestephen'],
#  ['asharonstone', 'averhoevenpauli'],
#  ['asharonstone', 'amillergeorgei'],
#  ['asharonstone', 'acatonjonesmichael'],
#  ['aellenthomas', 'acatonjonesmichael'],
#  ['adavidarnett', 'amillergeorgei'],
#  ['ajackmcgee', 'averhoevenpauli'],
#  ['awayneknight', 'averhoevenpauli'],
#  ['ajustinmonjo', 'amillergeorgei'],
#  ['ajaimzwoolvett', 'ametcalfestephen'],
#  ['atimberrington', 'acatonjonesmichael'],
#  ['astephentobolowsky', 'averhoevenpauli'],
#  ['agilbellows', 'ametcalfestephen'],
#  ['adavidthewlis', 'acatonjonesmichael'],
#  ['aianholm', 'ametcalfestephen'],
#  ['abenjohnson', 'ametcalfestephen'],
#  ['adannflorek', 'ametcalfestephen'],
#  ['aheathcotewilliams', 'acatonjonesmichael'],
#  ['acharlotterampling', 'acatonjonesmichael'],
#  ['achelcieross', 'averhoevenpauli'],
#  ['astevekuhn', 'amillergeorgei'],
#  ['amarksangster', 'acatonjonesmichael'],
#  ['aindiravarma', 'acatonjonesmichael'],
#  ['ahughkeaysbyrne', 'amillergeorgei'],
#  ['aginachiarelli', 'ametcalfestephen'],
#  ['abruceayoung', 'averhoevenpauli'],
#  ['adavidmorrissey', 'acatonjonesmichael'],
#  ['amiguelferrer', 'amillergeorgei'],
#  ['adorothymalone', 'averhoevenpauli'],
#  ['ageorgedzundza', 'averhoevenpauli'],
#  ['ahughdancy', 'acatonjonesmichael'],
#  ['abillcable', 'averhoevenpauli'],
#  ['amarccaleb', 'amillergeorgei'],
#  ['afrankcturner', 'ametcalfestephen'],
#  ['aalancpeterson', 'ametcalfestephen'],
#  ['anormanarmour', 'ametcalfestephen'],
#  ['ajurneesmollett', 'ametcalfestephen'],
#  ['ajanchappell', 'acatonjonesmichael'],
#  ['agusmercurio', 'amillergeorgei'],
#  ['acaitlinoheaney', 'amillergeorgei'],
#  ['aterenceharvey', 'acatonjonesmichael'],
#  ['adillonmoen', 'ametcalfestephen'],
#  ['aleilanisarelle', 'averhoevenpauli'],
#  ['alloydalan', 'amillergeorgei'],
#  ['aconnorwiddows', 'ametcalfestephen'],
#  ['adebraengle', 'amillergeorgei'],
#  ['arobyndouglass'],
#  ['afloramontgomery'],
#  ['asheilapaterson'],
#  ['ajeannetripplehorn'],
#  ['asharonstone'],
#  ['aellenthomas'],
#  ['atimberrington'],
#  ['acharlotterampling'],
#  ['achelcieross'],
#  ['amarksangster'],
#  ['aginachiarelli'],
#  ['adorothymalone'],
#  ['ajurneesmollett'],
#  ['ajanchappell'],
#  ['acaitlinoheaney'],
#  ['aleilanisarelle'],
#  ['adebraengle'],
#  ['amichaeldouglas'],
#  ['arobyndouglass'],
#  ['alewissmith'],
#  ['abillyconnolly'],
#  ['adanielvonbargen'],
#  ['adenisarndt'],
#  ['afloramontgomery'],
#  ['asheilapaterson'],
#  ['astancollymore'],
#  ['abenjaminmouton'],
#  ['ajeannetripplehorn'],
#  ['aneilmaskell'],
#  ['asharonstone'],
#  ['aellenthomas'],
#  ['adavidarnett'],
#  ['ajackmcgee'],
#  ['awayneknight'],
#  ['ajustinmonjo'],
#  ['ajaimzwoolvett'],
#  ['atimberrington'],
#  ['astephentobolowsky'],
#  ['agilbellows'],
#  ['adavidthewlis'],
#  ['aianholm'],
#  ['abenjohnson'],
#  ['adannflorek'],
#  ['aheathcotewilliams'],
#  ['acharlotterampling'],
#  ['achelcieross'],
#  ['astevekuhn'],
#  ['amarksangster'],
#  ['aindiravarma'],
#  ['ahughkeaysbyrne'],
#  ['aginachiarelli'],
#  ['abruceayoung'],
#  ['adavidmorrissey'],
#  ['amiguelferrer'],
#  ['adorothymalone'],
#  ['ageorgedzundza'],
#  ['ahughdancy'],
#  ['abillcable'],
#  ['amarccaleb'],
#  ['afrankcturner'],
#  ['aalancpeterson'],
#  ['anormanarmour'],
#  ['ajurneesmollett'],
#  ['ajanchappell'],
#  ['agusmercurio'],
#  ['acaitlinoheaney'],
#  ['aterenceharvey'],
#  ['adillonmoen'],
#  ['aleilanisarelle'],
#  ['alloydalan'],
#  ['aconnorwiddows'],
#  ['adebraengle'],
#  ['ametcalfestephen'],
#  ['averhoevenpauli'],
#  ['amillergeorgei'],
#  ['acatonjonesmichael'],
#  ['abeautifuljoe', 'abillyconnolly'],
#  ['abeautifuljoe', 'asheilapaterson'],
#  ['abeautifuljoe', 'asharonstone'],
#  ['abeautifuljoe', 'ajaimzwoolvett'],
#  ['abeautifuljoe', 'agilbellows'],
#  ['abeautifuljoe', 'aianholm'],
#  ['abeautifuljoe', 'abenjohnson'],
#  ['abeautifuljoe', 'adannflorek'],
#  ['abeautifuljoe', 'aginachiarelli'],
#  ['abeautifuljoe', 'afrankcturner'],
#  ['abeautifuljoe', 'aalancpeterson'],
#  ['abeautifuljoe', 'anormanarmour'],
#  ['abeautifuljoe', 'ajurneesmollett'],
#  ['abeautifuljoe', 'adillonmoen'],
#  ['abeautifuljoe', 'aconnorwiddows'],
#  ['abeautifuljoe', 'ametcalfestephen'],
#  ['abasicinstinct2', 'afloramontgomery'],
#  ['abasicinstinct2', 'astancollymore'],
#  ['abasicinstinct2', 'aneilmaskell'],
#  ['abasicinstinct2', 'asharonstone'],
#  ['abasicinstinct2', 'aellenthomas'],
#  ['abasicinstinct2', 'atimberrington'],
#  ['abasicinstinct2', 'adavidthewlis'],
#  ['abasicinstinct2', 'aheathcotewilliams'],
#  ['abasicinstinct2', 'acharlotterampling'],
#  ['abasicinstinct2', 'amarksangster'],
#  ['abasicinstinct2', 'aindiravarma'],
#  ['abasicinstinct2', 'adavidmorrissey'],
#  ['abasicinstinct2', 'ahughdancy'],
#  ['abasicinstinct2', 'ajanchappell'],
#  ['abasicinstinct2', 'aterenceharvey'],
#  ['abasicinstinct2', 'acatonjonesmichael'],
#  ['abasicinstinct', 'amichaeldouglas'],
#  ['abasicinstinct', 'adanielvonbargen'],
#  ['abasicinstinct', 'adenisarndt'],
#  ['abasicinstinct', 'abenjaminmouton'],
#  ['abasicinstinct', 'ajeannetripplehorn'],
#  ['abasicinstinct', 'asharonstone'],
#  ['abasicinstinct', 'ajackmcgee'],
#  ['abasicinstinct', 'awayneknight'],
#  ['abasicinstinct', 'astephentobolowsky'],
#  ['abasicinstinct', 'achelcieross'],
#  ['abasicinstinct', 'abruceayoung'],
#  ['abasicinstinct', 'adorothymalone'],
#  ['abasicinstinct', 'ageorgedzundza'],
#  ['abasicinstinct', 'abillcable'],
#  ['abasicinstinct', 'aleilanisarelle'],
#  ['abasicinstinct', 'averhoevenpauli'],
#  ['abadlands2005', 'arobyndouglass'],
#  ['abadlands2005', 'alewissmith'],
#  ['abadlands2005', 'asharonstone'],
#  ['abadlands2005', 'adavidarnett'],
#  ['abadlands2005', 'ajustinmonjo'],
#  ['abadlands2005', 'astevekuhn'],
#  ['abadlands2005', 'ahughkeaysbyrne'],
#  ['abadlands2005', 'amiguelferrer'],
#  ['abadlands2005', 'amarccaleb'],
#  ['abadlands2005', 'agusmercurio'],
#  ['abadlands2005', 'acaitlinoheaney'],
#  ['abadlands2005', 'alloydalan'],
#  ['abadlands2005', 'adebraengle'],
#  ['abadlands2005', 'amillergeorgei'],
#  ['akinkelmartin', 'acomedy'],
#  ['akinkelmartin', 'acrime'],
#  ['akronthalerthomas', 'acomedy'],
#  ['akronthalerthomas', 'acrime'],
#  ['aengelhardtwilhelm', 'acomedy'],
#  ['aengelhardtwilhelm', 'acrime'],
#  ['astephanbernhard', 'acrime'],
#  ['aapprederisfranck', 'acomedy'],
#  ['agutjahrrainer', 'acomedy'],
#  ['agutjahrrainer', 'acrime'],
#  ['akrgnther', 'acomedy'],
#  ['akrgnther', 'acrime'],
#  ['azensmichael', 'acrime'],
#  ['avergnejeanpierre', 'acomedy'],
#  ['abraunbettinai', 'acomedy'],
#  ['abraunbettinai', 'acrime'],
#  ['aklischstefan', 'acomedy'],
#  ['aklischstefan', 'acrime'],
#  ['avolkerranisch', 'astephanbernhard'],
#  ['avolkerranisch', 'azensmichael'],
#  ['aludwigbriand', 'aapprederisfranck'],
#  ['aludwigbriand', 'avergnejeanpierre'],
#  ['agerdlohmeyer', 'akinkelmartin'],
#  ['agerdlohmeyer', 'akronthalerthomas'],
#  ['agerdlohmeyer', 'aengelhardtwilhelm'],
#  ['agerdlohmeyer', 'agutjahrrainer'],
#  ['agerdlohmeyer', 'akrgnther'],
#  ['agerdlohmeyer', 'abraunbettinai'],
#  ['agerdlohmeyer', 'aklischstefan'],
#  ['astevekalfa', 'aromeclaudemichel'],
#  ['astevekalfa', 'akappesstphane'],
#  ['astevekalfa', 'abonnetchristiani'],
#  ['astevekalfa', 'asummereric'],
#  ['astevekalfa', 'atonetticlaudio'],
#  ['astevekalfa', 'agustemmanuelii'],
#  ['astevekalfa', 'aladogedominique'],
#  ['aguillaumeromain', 'aapprederisfranck'],
#  ['aguillaumeromain', 'avergnejeanpierre'],
#  ['agabriellelazure', 'aromeclaudemichel'],
#  ['agabriellelazure', 'akappesstphane'],
#  ['agabriellelazure', 'abonnetchristiani'],
#  ['agabriellelazure', 'asummereric'],
#  ['agabriellelazure', 'atonetticlaudio'],
#  ['agabriellelazure', 'agustemmanuelii'],
#  ['agabriellelazure', 'aladogedominique'],
#  ['ahorstkummeth', 'akinkelmartin'],
#  ['ahorstkummeth', 'akronthalerthomas'],
#  ['ahorstkummeth', 'aengelhardtwilhelm'],
#  ['ahorstkummeth', 'agutjahrrainer'],
#  ['ahorstkummeth', 'akrgnther'],
#  ['ahorstkummeth', 'abraunbettinai'],
#  ['ahorstkummeth', 'aklischstefan'],
#  ['aloccorbery', 'aapprederisfranck'],
#  ['aloccorbery', 'avergnejeanpierre'],
#  ['ajuliedray', 'aapprederisfranck'],
#  ['ajuliedray', 'avergnejeanpierre'],
#  ['afirminerichard', 'aromeclaudemichel'],
#  ['afirminerichard', 'akappesstphane'],
#  ['afirminerichard', 'abonnetchristiani'],
#  ['afirminerichard', 'asummereric'],
#  ['afirminerichard', 'atonetticlaudio'],
#  ['afirminerichard', 'agustemmanuelii'],
#  ['afirminerichard', 'aladogedominique'],
#  ['ahubertmulzer', 'akinkelmartin'],
#  ['ahubertmulzer', 'akronthalerthomas'],
#  ['ahubertmulzer', 'aengelhardtwilhelm'],
#  ['ahubertmulzer', 'agutjahrrainer'],
#  ['ahubertmulzer', 'akrgnther'],
#  ['ahubertmulzer', 'abraunbettinai'],
#  ['ahubertmulzer', 'aklischstefan'],
#  ['asamantharnier', 'aapprederisfranck'],
#  ['asamantharnier', 'avergnejeanpierre'],
#  ['atommikulla', 'akinkelmartin'],
#  ['atommikulla', 'akronthalerthomas'],
#  ['atommikulla', 'aengelhardtwilhelm'],
#  ['atommikulla', 'agutjahrrainer'],
#  ['atommikulla', 'akrgnther'],
#  ['atommikulla', 'abraunbettinai'],
#  ['atommikulla', 'aklischstefan'],
#  ['acoralyzahonero', 'aromeclaudemichel'],
#  ['acoralyzahonero', 'akappesstphane'],
#  ['acoralyzahonero', 'abonnetchristiani'],
#  ['acoralyzahonero', 'asummereric'],
#  ['acoralyzahonero', 'atonetticlaudio'],
#  ['acoralyzahonero', 'agustemmanuelii'],
#  ['acoralyzahonero', 'aladogedominique'],
#  ['abrnicebejo', 'aapprederisfranck'],
#  ['abrnicebejo', 'avergnejeanpierre'],
#  ['abrigittefossey', 'aapprederisfranck'],
#  ['abrigittefossey', 'avergnejeanpierre'],
#  ['amaxmller', 'akinkelmartin'],
#  ['amaxmller', 'akronthalerthomas'],
#  ['amaxmller', 'aengelhardtwilhelm'],
#  ['amaxmller', 'agutjahrrainer'],
#  ['amaxmller', 'akrgnther'],
#  ['amaxmller', 'abraunbettinai'],
#  ['amaxmller', 'aklischstefan'],
#  ['amarenschumacher', 'akinkelmartin'],
#  ['amarenschumacher', 'akronthalerthomas'],
#  ['amarenschumacher', 'aengelhardtwilhelm'],
#  ['amarenschumacher', 'agutjahrrainer'],
#  ['amarenschumacher', 'akrgnther'],
#  ['amarenschumacher', 'abraunbettinai'],
#  ['amarenschumacher', 'aklischstefan'],
#  ['avincentlecoeur', 'aapprederisfranck'],
#  ['avincentlecoeur', 'avergnejeanpierre'],
#  ['aestefanacastro', 'aapprederisfranck'],
#  ['aestefanacastro', 'avergnejeanpierre'],
#  ['ajuttawachowiak', 'astephanbernhard'],
#  ['ajuttawachowiak', 'azensmichael'],
#  ['aarmelledeutsch', 'aapprederisfranck'],
#  ['aarmelledeutsch', 'avergnejeanpierre'],
#  ['athomasstielner', 'akinkelmartin'],
#  ['athomasstielner', 'akronthalerthomas'],
#  ['athomasstielner', 'aengelhardtwilhelm'],
#  ['athomasstielner', 'agutjahrrainer'],
#  ['athomasstielner', 'akrgnther'],
#  ['athomasstielner', 'abraunbettinai'],
#  ['athomasstielner', 'aklischstefan'],
#  ['afranoisechristophe', 'aromeclaudemichel'],
#  ['afranoisechristophe', 'akappesstphane'],
#  ['afranoisechristophe', 'abonnetchristiani'],
#  ['afranoisechristophe', 'asummereric'],
#  ['afranoisechristophe', 'atonetticlaudio'],
#  ['afranoisechristophe', 'agustemmanuelii'],
#  ['afranoisechristophe', 'aladogedominique'],
#  ['apierrearditi', 'aapprederisfranck'],
#  ['apierrearditi', 'avergnejeanpierre'],
#  ['aclaudiamessner', 'astephanbernhard'],
#  ['aclaudiamessner', 'azensmichael'],
#  ['amarisaburger', 'akinkelmartin'],
#  ['amarisaburger', 'akronthalerthomas'],
#  ['amarisaburger', 'aengelhardtwilhelm'],
#  ['amarisaburger', 'agutjahrrainer'],
#  ['amarisaburger', 'akrgnther'],
#  ['amarisaburger', 'abraunbettinai'],
#  ['amarisaburger', 'aklischstefan'],
#  ['afrancishuster', 'aromeclaudemichel'],
#  ['afrancishuster', 'akappesstphane'],
#  ['afrancishuster', 'abonnetchristiani'],
#  ['afrancishuster', 'asummereric'],
#  ['afrancishuster', 'atonetticlaudio'],
#  ['afrancishuster', 'agustemmanuelii'],
#  ['afrancishuster', 'aladogedominique'],
#  ['atheresascholze', 'astephanbernhard'],
#  ['atheresascholze', 'azensmichael'],
#  ['aalexandrawinisky', 'aapprederisfranck'],
#  ['aalexandrawinisky', 'avergnejeanpierre'],
#  ['aandreasschwaiger', 'akinkelmartin'],
#  ['aandreasschwaiger', 'akronthalerthomas'],
#  ['aandreasschwaiger', 'aengelhardtwilhelm'],
#  ['aandreasschwaiger', 'astephanbernhard'],
#  ['aandreasschwaiger', 'agutjahrrainer'],
#  ['aandreasschwaiger', 'akrgnther'],
#  ['aandreasschwaiger', 'azensmichael'],
#  ['aandreasschwaiger', 'abraunbettinai'],
#  ['aandreasschwaiger', 'aklischstefan'],
#  ['akarinthaler', 'akinkelmartin'],
#  ['akarinthaler', 'akronthalerthomas'],
#  ['akarinthaler', 'aengelhardtwilhelm'],
#  ['akarinthaler', 'agutjahrrainer'],
#  ['akarinthaler', 'akrgnther'],
#  ['akarinthaler', 'abraunbettinai'],
#  ['akarinthaler', 'aklischstefan'],
#  ['arenateschroeter', 'astephanbernhard'],
#  ['arenateschroeter', 'azensmichael'],
#  ['adidierdijoux', 'aapprederisfranck'],
#  ['adidierdijoux', 'avergnejeanpierre'],
#  ['agesinecukrowski', 'astephanbernhard'],
#  ['agesinecukrowski', 'azensmichael'],
#  ['akonstanzebreitebner', 'astephanbernhard'],
#  ['akonstanzebreitebner', 'azensmichael'],
#  ['amarkusbker', 'akinkelmartin'],
#  ['amarkusbker', 'akronthalerthomas'],
#  ['amarkusbker', 'aengelhardtwilhelm'],
#  ['amarkusbker', 'agutjahrrainer'],
#  ['amarkusbker', 'akrgnther'],
#  ['amarkusbker', 'abraunbettinai'],
#  ['amarkusbker', 'aklischstefan'],
#  ['ajrggudzuhn', 'astephanbernhard'],
#  ['ajrggudzuhn', 'azensmichael'],
#  ['adietermann', 'astephanbernhard'],
#  ['adietermann', 'azensmichael'],
#  ['apatricejuiff', 'aapprederisfranck'],
#  ['apatricejuiff', 'avergnejeanpierre'],
#  ['accilecassel', 'aromeclaudemichel'],
#  ['accilecassel', 'akappesstphane'],
#  ['accilecassel', 'abonnetchristiani'],
#  ['accilecassel', 'asummereric'],
#  ['accilecassel', 'atonetticlaudio'],
#  ['accilecassel', 'agustemmanuelii'],
#  ['accilecassel', 'aladogedominique'],
#  ['aleonardlansink', 'astephanbernhard'],
#  ['aleonardlansink', 'azensmichael'],
#  ['aulrichmhe', 'astephanbernhard'],
#  ['aulrichmhe', 'azensmichael'],
#  ['agabriellelazure'],
#  ['ajuliedray'],
#  ['afirminerichard'],
#  ['asamantharnier'],
#  ['acoralyzahonero'],
#  ['abrnicebejo'],
#  ['abrigittefossey'],
#  ['amarenschumacher'],
#  ['aestefanacastro'],
#  ['ajuttawachowiak'],
#  ['aarmelledeutsch'],
#  ['afranoisechristophe'],
#  ['aclaudiamessner'],
#  ['amarisaburger'],
#  ['afrancishuster'],
#  ['atheresascholze'],
#  ['aalexandrawinisky'],
#  ['akarinthaler'],
#  ['arenateschroeter'],
#  ['agesinecukrowski'],
#  ['akonstanzebreitebner'],
#  ['accilecassel'],
#  ['avolkerranisch'],
#  ['aludwigbriand'],
#  ['agerdlohmeyer'],
#  ['astevekalfa'],
#  ['aguillaumeromain'],
#  ['agabriellelazure'],
#  ['ahorstkummeth'],
#  ['aloccorbery'],
#  ['ajuliedray'],
#  ['afirminerichard'],
#  ['ahubertmulzer'],
#  ['asamantharnier'],
#  ['atommikulla'],
#  ['acoralyzahonero'],
#  ['abrnicebejo'],
#  ['abrigittefossey'],
#  ['amaxmller'],
#  ['amarenschumacher'],
#  ['avincentlecoeur'],
#  ['aestefanacastro'],
#  ['ajuttawachowiak'],
#  ['aarmelledeutsch'],
#  ['athomasstielner'],
#  ['afranoisechristophe'],
#  ['apierrearditi'],
#  ['aclaudiamessner'],
#  ['amarisaburger'],
#  ['afrancishuster'],
#  ['atheresascholze'],
#  ['aalexandrawinisky'],
#  ['aandreasschwaiger'],
#  ['akarinthaler'],
#  ['arenateschroeter'],
#  ['adidierdijoux'],
#  ['agesinecukrowski'],
#  ['akonstanzebreitebner'],
#  ['amarkusbker'],
#  ['ajrggudzuhn'],
#  ['adietermann'],
#  ['apatricejuiff'],
#  ['accilecassel'],
#  ['aleonardlansink'],
#  ['aulrichmhe'],
#  ['akinkelmartin'],
#  ['akronthalerthomas'],
#  ['aengelhardtwilhelm'],
#  ['astephanbernhard'],
#  ['aromeclaudemichel'],
#  ['akappesstphane'],
#  ['aapprederisfranck'],
#  ['agutjahrrainer'],
#  ['akrgnther'],
#  ['abonnetchristiani'],
#  ['asummereric'],
#  ['azensmichael'],
#  ['atonetticlaudio'],
#  ['avergnejeanpierre'],
#  ['abraunbettinai'],
#  ['agustemmanuelii'],
#  ['aklischstefan'],
#  ['aladogedominique'],
#  ['aunetunfontsix', 'aludwigbriand'],
#  ['aunetunfontsix', 'aguillaumeromain'],
#  ['aunetunfontsix', 'aloccorbery'],
#  ['aunetunfontsix', 'ajuliedray'],
#  ['aunetunfontsix', 'asamantharnier'],
#  ['aunetunfontsix', 'abrnicebejo'],
#  ['aunetunfontsix', 'abrigittefossey'],
#  ['aunetunfontsix', 'avincentlecoeur'],
#  ['aunetunfontsix', 'aestefanacastro'],
#  ['aunetunfontsix', 'aarmelledeutsch'],
#  ['aunetunfontsix', 'apierrearditi'],
#  ['aunetunfontsix', 'aalexandrawinisky'],
#  ['aunetunfontsix', 'adidierdijoux'],
#  ['aunetunfontsix', 'apatricejuiff'],
#  ['aunetunfontsix', 'aapprederisfranck'],
#  ['aunetunfontsix', 'avergnejeanpierre'],
#  ['aletztezeugeder', 'avolkerranisch'],
#  ['aletztezeugeder', 'ajuttawachowiak'],
#  ['aletztezeugeder', 'aclaudiamessner'],
#  ['aletztezeugeder', 'atheresascholze'],
#  ['aletztezeugeder', 'aandreasschwaiger'],
#  ['aletztezeugeder', 'arenateschroeter'],
#  ['aletztezeugeder', 'agesinecukrowski'],
#  ['aletztezeugeder', 'akonstanzebreitebner'],
#  ['aletztezeugeder', 'ajrggudzuhn'],
#  ['aletztezeugeder', 'adietermann'],
#  ['aletztezeugeder', 'aleonardlansink'],
#  ['aletztezeugeder', 'aulrichmhe'],
#  ['aletztezeugeder', 'astephanbernhard'],
#  ['aletztezeugeder', 'azensmichael'],
#  ['agrandpatronle', 'astevekalfa'],
#  ['agrandpatronle', 'agabriellelazure'],
#  ['agrandpatronle', 'afirminerichard'],
#  ['agrandpatronle', 'acoralyzahonero'],
#  ['agrandpatronle', 'afranoisechristophe'],
#  ['agrandpatronle', 'afrancishuster'],
#  ['agrandpatronle', 'accilecassel'],
#  ['agrandpatronle', 'aromeclaudemichel'],
#  ['agrandpatronle', 'akappesstphane'],
#  ['agrandpatronle', 'abonnetchristiani'],
#  ['agrandpatronle', 'asummereric'],
#  ['agrandpatronle', 'atonetticlaudio'],
#  ['agrandpatronle', 'agustemmanuelii'],
#  ['agrandpatronle', 'aladogedominique'],
#  ['arosenheimcopsdie', 'agerdlohmeyer'],
#  ['arosenheimcopsdie', 'ahorstkummeth'],
#  ['arosenheimcopsdie', 'ahubertmulzer'],
#  ['arosenheimcopsdie', 'atommikulla'],
#  ['arosenheimcopsdie', 'amaxmller'],
#  ['arosenheimcopsdie', 'amarenschumacher'],
#  ['arosenheimcopsdie', 'athomasstielner'],
#  ['arosenheimcopsdie', 'amarisaburger'],
#  ['arosenheimcopsdie', 'aandreasschwaiger'],
#  ['arosenheimcopsdie', 'akarinthaler'],
#  ['arosenheimcopsdie', 'amarkusbker'],
#  ['arosenheimcopsdie', 'akinkelmartin'],
#  ['arosenheimcopsdie', 'akronthalerthomas'],
#  ['arosenheimcopsdie', 'aengelhardtwilhelm'],
#  ['arosenheimcopsdie', 'agutjahrrainer'],
#  ['arosenheimcopsdie', 'akrgnther'],
#  ['arosenheimcopsdie', 'abraunbettinai'],
#  ['arosenheimcopsdie', 'aklischstefan'],
#  ['atraykovatanas', 'adrama'],
#  ['apunchevborislav', 'adrama'],
#  ['amarinovichanton', 'adrama'],
#  ['asurchadzhievstefani', 'adrama'],
#  ['aangelinasarova', 'amarinovichanton'],
#  ['aangelinasarova', 'asurchadzhievstefani'],
#  ['aivankondov', 'asurchadzhievstefani'],
#  ['akirilyanev', 'asurchadzhievstefani'],
#  ['astoychomazgalov', 'atraykovatanas'],
#  ['astoychomazgalov', 'apunchevborislav'],
#  ['astoychomazgalov', 'asurchadzhievstefani'],
#  ['amikhailmikhajlov', 'asurchadzhievstefani'],
#  ['aganchoganchev', 'amarinovichanton'],
#  ['amichalbajor', 'apunchevborislav'],
#  ['ahristodinev', 'asurchadzhievstefani'],
#  ['avyarakovacheva', 'amarinovichanton'],
#  ['apetardespotov', 'atraykovatanas'],
#  ['asavahashamov', 'asurchadzhievstefani'],
#  ['alyubomirbobchevski', 'asurchadzhievstefani'],
#  ['amariashopova', 'amarinovichanton'],
#  ['akostatsonev', 'atraykovatanas'],
#  ['akostatsonev', 'apunchevborislav'],
#  ['astefandanailov', 'atraykovatanas'],
#  ['aivanbratanov', 'amarinovichanton'],
#  ['aemiliaradeva', 'atraykovatanas'],
#  ['ageorgistamatov', 'amarinovichanton'],
#  ['astefanpejchev', 'amarinovichanton'],
#  ['adimitarhadzhiyanev', 'atraykovatanas'],
#  ['ajannowicki', 'apunchevborislav'],
#  ['aalicjajachiewicz', 'apunchevborislav'],
#  ['asonyadjulgerova', 'atraykovatanas'],
#  ['aviktordanchenko', 'asurchadzhievstefani'],
#  ['akunkabaeva', 'amarinovichanton'],
#  ['aantonradichev', 'apunchevborislav'],
#  ['aemilmarkov', 'apunchevborislav'],
#  ['astefanpetrov', 'amarinovichanton'],
#  ['atzenokandov', 'asurchadzhievstefani'],
#  ['alyubomirbachvarov', 'apunchevborislav'],
#  ['aivandimov', 'amarinovichanton'],
#  ['aivangrigorov', 'atraykovatanas'],
#  ['alyubomirkanev', 'apunchevborislav'],
#  ['atzvetolyubrakovski', 'amarinovichanton'],
#  ['asotirmaynolovski', 'apunchevborislav'],
#  ['aivantonev', 'amarinovichanton'],
#  ['abogomilsimeonov', 'apunchevborislav'],
#  ['anevenakokanova', 'atraykovatanas'],
#  ['anevenakokanova', 'apunchevborislav'],
#  ['anikoladadov', 'amarinovichanton'],
#  ['apetyasilyanova', 'atraykovatanas'],
#  ['aangelinasarova'],
#  ['avyarakovacheva'],
#  ['amariashopova'],
#  ['aemiliaradeva'],
#  ['aalicjajachiewicz'],
#  ['asonyadjulgerova'],
#  ['akunkabaeva'],
#  ['anevenakokanova'],
#  ['apetyasilyanova'],
#  ['aangelinasarova'],
#  ['aivankondov'],
#  ['akirilyanev'],
#  ['astoychomazgalov'],
#  ['amikhailmikhajlov'],
#  ['aganchoganchev'],
#  ['amichalbajor'],
#  ['ahristodinev'],
#  ['avyarakovacheva'],
#  ['apetardespotov'],
#  ['asavahashamov'],
#  ['alyubomirbobchevski'],
#  ['amariashopova'],
#  ['akostatsonev'],
#  ['astefandanailov'],
#  ['aivanbratanov'],
#  ['aemiliaradeva'],
#  ['ageorgistamatov'],
#  ['astefanpejchev'],
#  ['adimitarhadzhiyanev'],
#  ['ajannowicki'],
#  ['aalicjajachiewicz'],
#  ['asonyadjulgerova'],
#  ['aviktordanchenko'],
#  ['akunkabaeva'],
#  ['aantonradichev'],
#  ['aemilmarkov'],
#  ['astefanpetrov'],
#  ['atzenokandov'],
#  ['alyubomirbachvarov'],
#  ['aivandimov'],
#  ['aivangrigorov'],
#  ['alyubomirkanev'],
#  ['atzvetolyubrakovski'],
#  ['asotirmaynolovski'],
#  ['aivantonev'],
#  ['abogomilsimeonov'],
#  ['anevenakokanova'],
#  ['anikoladadov'],
#  ['apetyasilyanova'],
#  ['atraykovatanas'],
#  ['apunchevborislav'],
#  ['amarinovichanton'],
#  ['asurchadzhievstefani'],
#  ['ageratzite', 'aangelinasarova'],
#  ['ageratzite', 'aganchoganchev'],
#  ['ageratzite', 'avyarakovacheva'],
#  ['ageratzite', 'amariashopova'],
#  ['ageratzite', 'aivanbratanov'],
#  ['ageratzite', 'ageorgistamatov'],
#  ['ageratzite', 'astefanpejchev'],
#  ['ageratzite', 'akunkabaeva'],
#  ['ageratzite', 'astefanpetrov'],
#  ['ageratzite', 'aivandimov'],
#  ['ageratzite', 'atzvetolyubrakovski'],
#  ['ageratzite', 'aivantonev'],
#  ['ageratzite', 'anikoladadov'],
#  ['ageratzite', 'amarinovichanton'],
#  ['aspasenieto', 'astoychomazgalov'],
#  ['aspasenieto', 'amichalbajor'],
#  ['aspasenieto', 'akostatsonev'],
#  ['aspasenieto', 'ajannowicki'],
#  ['aspasenieto', 'aalicjajachiewicz'],
#  ['aspasenieto', 'aantonradichev'],
#  ['aspasenieto', 'aemilmarkov'],
#  ['aspasenieto', 'alyubomirbachvarov'],
#  ['aspasenieto', 'alyubomirkanev'],
#  ['aspasenieto', 'asotirmaynolovski'],
#  ['aspasenieto', 'abogomilsimeonov'],
#  ['aspasenieto', 'anevenakokanova'],
#  ['aspasenieto', 'apunchevborislav'],
#  ['akristali', 'astoychomazgalov'],
#  ['akristali', 'apetardespotov'],
#  ['akristali', 'akostatsonev'],
#  ['akristali', 'astefandanailov'],
#  ['akristali', 'aemiliaradeva'],
#  ['akristali', 'adimitarhadzhiyanev'],
#  ['akristali', 'asonyadjulgerova'],
#  ['akristali', 'aivangrigorov'],
#  ['akristali', 'anevenakokanova'],
#  ['akristali', 'apetyasilyanova'],
#  ['akristali', 'atraykovatanas'],
#  ['alegendazapaisiy', 'aangelinasarova'],
#  ['alegendazapaisiy', 'aivankondov'],
#  ['alegendazapaisiy', 'akirilyanev'],
#  ['alegendazapaisiy', 'astoychomazgalov'],
#  ['alegendazapaisiy', 'amikhailmikhajlov'],
#  ['alegendazapaisiy', 'ahristodinev'],
#  ['alegendazapaisiy', 'asavahashamov'],
#  ['alegendazapaisiy', 'alyubomirbobchevski'],
#  ['alegendazapaisiy', 'aviktordanchenko'],
#  ['alegendazapaisiy', 'atzenokandov'],
#  ['alegendazapaisiy', 'asurchadzhievstefani'],
#  ['agrimaldiaurelioi', 'adrama'],
#  ['abattiatofranco', 'adrama'],
#  ['aluciacammalleri', 'asciveresmarianna'],
#  ['agiancarloscuderi', 'agrimaldiaurelioi'],
#  ['araffaeladavi', 'agrimaldiaurelioi'],
#  ['aenzodimartino', 'agrimaldiaurelioi'],
#  ['aconsuelolupo', 'asciveresmarianna'],
#  ['afrancomirabella', 'agrimaldiaurelioi'],
#  ['abiagiobarone', 'asciveresmarianna'],
#  ['acesareapolito', 'agrimaldiaurelioi'],
#  ['astefanodionisi', 'agrimaldiaurelioi'],
#  ['afabiolobello', 'agrimaldiaurelioi'],
#  ['amanueladolcemascolo', 'asciveresmarianna'],
#  ['acorradofortuna', 'abattiatofranco'],
#  ['aannamariagherardi', 'abattiatofranco'],
#  ['amarcocavicchioli', 'agrimaldiaurelioi'],
#  ['adonatellafinocchiaro', 'abattiatofranco'],
#  ['adanielegalea', 'agrimaldiaurelioi'],
#  ['apaolaciampi', 'agrimaldiaurelioi'],
#  ['amanliosgalambro', 'abattiatofranco'],
#  ['agabrieleferzetti', 'abattiatofranco'],
#  ['aantoniettacarbonetti', 'agrimaldiaurelioi'],
#  ['aantoninobruschetta', 'abattiatofranco'],
#  ['amaurizionicolosi', 'agrimaldiaurelioi'],
#  ['amaurolenares', 'agrimaldiaurelioi'],
#  ['asalvatorelazzaro', 'agrimaldiaurelioi'],
#  ['apieradegliesposti', 'agrimaldiaurelioi'],
#  ['amarcoleonardi', 'agrimaldiaurelioi'],
#  ['aserenaautieri', 'asciveresmarianna'],
#  ['aradarassimov', 'abattiatofranco'],
#  ['aileanarigano', 'asciveresmarianna'],
#  ['avincenzocrivello', 'agrimaldiaurelioi'],
#  ['amarcospicuglia', 'agrimaldiaurelioi'],
#  ['asaromiano', 'agrimaldiaurelioi'],
#  ['atizianalodato', 'abattiatofranco'],
#  ['anicolegrimaudo', 'abattiatofranco'],
#  ['alaurabetti', 'agrimaldiaurelioi'],
#  ['aluciasardo', 'asciveresmarianna'],
#  ['aluciasardo', 'agrimaldiaurelioi'],
#  ['aluciasardo', 'abattiatofranco'],
#  ['acarmelogalati', 'asciveresmarianna'],
#  ['avannifois', 'asciveresmarianna'],
#  ['aauroraquattrocchi', 'agrimaldiaurelioi'],
#  ['abarbaratabita', 'asciveresmarianna'],
#  ['alucavitrano', 'abattiatofranco'],
#  ['apenlopecruz', 'agrimaldiaurelioi'],
#  ['aeddasabatini', 'agrimaldiaurelioi'],
#  ['aluciacammalleri'],
#  ['araffaeladavi'],
#  ['afrancomirabella'],
#  ['amanueladolcemascolo'],
#  ['aannamariagherardi'],
#  ['adonatellafinocchiaro'],
#  ['apaolaciampi'],
#  ['agabrieleferzetti'],
#  ['aantoniettacarbonetti'],
#  ['apieradegliesposti'],
#  ['aserenaautieri'],
#  ['aradarassimov'],
#  ['aileanarigano'],
#  ['atizianalodato'],
#  ['anicolegrimaudo'],
#  ['alaurabetti'],
#  ['aluciasardo'],
#  ['aauroraquattrocchi'],
#  ['abarbaratabita'],
#  ['apenlopecruz'],
#  ['aeddasabatini'],
#  ['aluciacammalleri'],
#  ['agiancarloscuderi'],
#  ['araffaeladavi'],
#  ['aenzodimartino'],
#  ['aconsuelolupo'],
#  ['afrancomirabella'],
#  ['abiagiobarone'],
#  ['acesareapolito'],
#  ['astefanodionisi'],
#  ['afabiolobello'],
#  ['amanueladolcemascolo'],
#  ['acorradofortuna'],
#  ['aannamariagherardi'],
#  ['amarcocavicchioli'],
#  ['adonatellafinocchiaro'],
#  ['adanielegalea'],
#  ['apaolaciampi'],
#  ...]

# %%
len(datasets.group_folds(dt[1]))
# Out:
# 382

# %%
# Out:
# 208
